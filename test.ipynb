# %%
from mss import mss
import cv2
import numpy as np
import pyautogui
from PIL import Image

# %%
width, height = pyautogui.size()
top = 0
left  = int(width * 0.4)
width = int(width * 0.4)
print(width, height)
# Out:
# 1152 1800

# %%
left_note = cv2.imread("left_note.png")
right_note = cv2.imread("right_note.png")

# %%
with mss() as sct:
    monitor = {'top': top, 'left': left, 'width': width, 'height': height}
    screenshot = sct.grab(monitor)
    img = np.array(screenshot)

    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
